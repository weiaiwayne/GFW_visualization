# %%
get_ipython().magic(u'pwd')
get_ipython().magic(u'cd "C:/Users/Wayne/Dropbox/Acer Laptop Sync/Data Science/GFW Visualization"')

import pandas as pd
from pandas import DataFrame
import plotly.plotly as py
from plotly.graph_objs import *
import cufflinks as cf

community_metrics_df = pd.read_csv("community_metrics_df.csv")
basic_network_level_measure = community_metrics_df[['Time frame','# of nodes','# of edges']]
community_count = community_metrics_df[['Time frame','# of communities']]
community_metric = community_metrics_df[['Time frame','modularity','proportion of nodes in the largest community','proportion of edges in the largest community']]
# Out:
# C:\Users\Wayne\Dropbox\Acer Laptop Sync\Data Science\GFW Visualization

# %%
community_metric
# Out:
#   Time frame  modularity  proportion of nodes in the largest community  \
# 0     Week 1        0.74                                        0.5936
# 1     Week 2        0.71                                        0.5516
# 2     Week 3        0.79                                        0.5680
# 3     Week 4        0.77                                        0.6146
# 4     Week 5        0.78                                        0.5729
# 5     Week 6        0.83                                        0.5585
# 6     Week 7        0.78                                        0.6035
# 7     Week 8        0.78                                        0.5957
#
#    proportion of edges in the largest community
# 0                                        0.6987
# 1                                        0.6064
# 2                                        0.6715
# 3                                        0.6496
# 4                                        0.6655
# ...

# %%
py.sign_in('cosmopolitanvan', 'jnv1ti79zi')

trace1 = Scatter(
    x = community_metric['Time frame'],
    y = community_metric['proportion of nodes in the largest community'],
    mode ='lines+markers',
    name ='Proportion of nodes in the largest cluster',
    error_y=ErrorY(
        color='rgb(0,116,217)',
        thickness=1,
        width=1
    ),
    error_x=ErrorX(
        color='black',
        thickness='1',
        width='2',
        copy_ystyle=True
    ),
    marker=Marker(
        color='rgb(19, 27, 88)',
        size=6,
        symbol='dot',
        line=Line(
            color='white',
            width=6
        ),
        opacity=1,
        maxdisplayed=0
    ),
    line=Line(
        color='rgb(19, 27, 88)',
        width=6,
        dash='solid',
        shape='linear'
    ),
    fill='none',
    opacity=1,
    visible=True,
    xsrc='cosmopolitanvan:195:f4aa23',
    ysrc='cosmopolitanvan:195:eef505'
)
trace2 = Scatter(
    x= community_metric['Time frame'],
    y= community_metric['proportion of edges in the largest community'],
    mode='lines+markers',
    name='Proportion of edges in the largest cluster',
    error_y=ErrorY(
        color='rgb(255,65,54)',
        thickness=1,
        width=1
    ),
    error_x=ErrorX(
        color='black',
        thickness='1',
        width='2',
        copy_ystyle=True
    ),
    marker=Marker(
        color='rgb(0, 167, 141)',
        size=6,
        symbol='dot',
        line=Line(
            color='white',
            width=6
        ),
        opacity=1,
        maxdisplayed=0
    ),
    line=Line(
        color='rgb(0, 167, 141)',
        width=6,
        dash='solid',
        shape='linear'
    ),
    fill='none',
    opacity=1,
    xsrc='cosmopolitanvan:195:f4aa23',
    ysrc='cosmopolitanvan:195:27bd7c'
)
trace3 =Scatter(
    x=community_metric['Time frame'],
    y=community_metric['modularity'],
    mode='lines+markers',
    name='modularity',
    error_y=ErrorY(
        color='rgb(133,20,75)',
        thickness=1,
        width=1
    ),
    error_x=ErrorX(
        color='black',
        thickness='1',
        width='2',
        copy_ystyle=True
    ),
    marker=Marker(
        color='rgb(252, 185, 37)',
        size=6,
        symbol='dot',
        line=Line(
            color='white',
            width=6
        ),
        opacity=1,
        maxdisplayed=0
    ),
    line=Line(
        color='rgb(252, 185, 37)',
        width=6,
        dash='solid',
        shape='linear'
    ),
    fill='none',
    opacity=1,
    xsrc='cosmopolitanvan:195:f4aa23',
    ysrc='cosmopolitanvan:195:628b9d'
)

data1 = Data([trace1, trace2, trace3])
layout = Layout(
    title='Trends in Clustering',
    titlefont=Font(
        family='"Open sans", verdana, arial, sans-serif',
        size=17,
        color='#444'
    ),
    font=Font(
        family='"Droid Sans", sans-serif',
        size=12,
        color='#444'
    ),
    autosize=True,
    width=1043,
    height=480,
    xaxis=XAxis(
        title='Time frame',
        titlefont=Font(
            family='"Verdana", monospace',
            size=12,
            color='black'
        ),
        range=[-0.3540280857354028, 4.354028085735402],
        type='category',
        rangemode='normal',
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        nticks=0,
        ticks='',
        showticklabels=True,
        ticklen=6,
        tickcolor='rgba(0, 0, 0, 0)',
        tickangle='auto',
        tickfont=Font(
            family='"Verdana", monospace',
            size=10,
            color='black'
        ),
        mirror='allticks',
        gridcolor='white',
        gridwidth=1,
        zerolinecolor='#444',
        zerolinewidth=1,
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    yaxis=YAxis(
        titlefont=Font(
            family='"Verdana", monospace',
            size=12,
            color='black'
        ),
        range=[0.5346071428571428, 0.8176928571428572],
        type='linear',
        rangemode='normal',
        autorange=True,
        showgrid=True,
        zeroline=False,
        showline=False,
        nticks=0,
        ticks='',
        showticklabels=True,
        ticklen=6,
        tickcolor='rgba(0, 0, 0, 0)',
        tickangle='auto',
        tickfont=Font(
            family='"Verdana", monospace',
            size=10,
            color='black'
        ),
        exponentformat='B',
        showexponent='all',
        mirror='allticks',
        gridcolor='white',
        gridwidth=1,
        zerolinecolor='#444',
        zerolinewidth=1,
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    legend=Legend(
        x=1.02,
        y=1,
        traceorder='normal',
        font=Font(
            family='"Open sans", verdana, arial, sans-serif',
            size=12,
            color='#444'
        ),
        bgcolor='#fff',
        bordercolor='#444',
        borderwidth=0,
        xref='paper',
        yref='paper'
    ),
    paper_bgcolor='rgb(213, 226, 233)',
    plot_bgcolor='rgb(213, 226, 233)',
    hovermode='x',
    dragmode='zoom',
    separators='.,',
    bargap=0.2,
    hidesources=False
)

fig = Figure(data=data1, layout=layout)

plot_url = py.plot(fig, filename='GFW/communitymetric_trend')
# Out:
# C:\Users\Wayne\Anaconda\lib\site-packages\requests\packages\urllib3\util\ssl_.py:90: InsecurePlatformWarning:
#
# A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.

# %%
py.sign_in('cosmopolitanvan', 'jnv1ti79zi')

trace1 = Scatter(
    x = basic_network_level_measure['Time frame'],
    y = basic_network_level_measure['# of nodes'],
    mode ='lines+markers',
    name ='# of nodes',
    error_y=ErrorY(
        color='rgb(0,116,217)',
        thickness=1,
        width=1
    ),
    error_x=ErrorX(
        color='black',
        thickness='1',
        width='2',
        copy_ystyle=True
    ),
    marker=Marker(
        color='rgb(19, 27, 88)',
        size=6,
        symbol='dot',
        line=Line(
            color='white',
            width=6
        ),
        opacity=1,
        maxdisplayed=0
    ),
    line=Line(
        color='rgb(19, 27, 88)',
        width=6,
        dash='solid',
        shape='linear'
    ),
    fill='none',
    opacity=1,
    visible=True,
    xsrc='cosmopolitanvan:195:f4aa23',
    ysrc='cosmopolitanvan:195:eef505'
)
trace2 = Scatter(
    x= basic_network_level_measure['Time frame'],
    y= basic_network_level_measure['# of edges'],
    mode='lines+markers',
    name='# of edges',
    error_y=ErrorY(
        color='rgb(255,65,54)',
        thickness=1,
        width=1
    ),
    error_x=ErrorX(
        color='black',
        thickness='1',
        width='2',
        copy_ystyle=True
    ),
    marker=Marker(
        color='rgb(0, 167, 141)',
        size=6,
        symbol='dot',
        line=Line(
            color='white',
            width=6
        ),
        opacity=1,
        maxdisplayed=0
    ),
    line=Line(
        color='rgb(0, 167, 141)',
        width=6,
        dash='solid',
        shape='linear'
    ),
    fill='none',
    opacity=1,
    xsrc='cosmopolitanvan:195:f4aa23',
    ysrc='cosmopolitanvan:195:27bd7c'
)

data2 = Data([trace1, trace2])
layout = Layout(
    title='Trends in Community Size',
    titlefont=Font(
        family='"Open sans", verdana, arial, sans-serif',
        size=17,
        color='#444'
    ),
    font=Font(
        family='"Droid Sans", sans-serif',
        size=12,
        color='#444'
    ),
    autosize=True,
    width=1043,
    height=480,
    xaxis=XAxis(
        title='Time frame',
        titlefont=Font(
            family='"Verdana", monospace',
            size=12,
            color='black'
        ),
        range=[-0.3540280857354028, 4.354028085735402],
        type='category',
        rangemode='normal',
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        nticks=0,
        ticks='',
        showticklabels=True,
        ticklen=6,
        tickcolor='rgba(0, 0, 0, 0)',
        tickangle='auto',
        tickfont=Font(
            family='"Verdana", monospace',
            size=10,
            color='black'
        ),
        mirror='allticks',
        gridcolor='white',
        gridwidth=1,
        zerolinecolor='#444',
        zerolinewidth=1,
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    yaxis=YAxis(
        titlefont=Font(
            family='"Verdana", monospace',
            size=12,
            color='black'
        ),
        range=[0.5346071428571428, 0.8176928571428572],
        type='linear',
        rangemode='normal',
        autorange=True,
        showgrid=True,
        zeroline=False,
        showline=False,
        nticks=0,
        ticks='',
        showticklabels=True,
        ticklen=6,
        tickcolor='rgba(0, 0, 0, 0)',
        tickangle='auto',
        tickfont=Font(
            family='"Verdana", monospace',
            size=10,
            color='black'
        ),
        exponentformat='B',
        showexponent='all',
        mirror='allticks',
        gridcolor='white',
        gridwidth=1,
        zerolinecolor='#444',
        zerolinewidth=1,
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    legend=Legend(
        x=1.02,
        y=1,
        traceorder='normal',
        font=Font(
            family='"Open sans", verdana, arial, sans-serif',
            size=12,
            color='#444'
        ),
        bgcolor='#fff',
        bordercolor='#444',
        borderwidth=0,
        xref='paper',
        yref='paper'
    ),
    paper_bgcolor='rgb(213, 226, 233)',
    plot_bgcolor='rgb(213, 226, 233)',
    hovermode='x',
    dragmode='zoom',
    separators='.,',
    bargap=0.2,
    hidesources=False
)

fig = Figure(data=data2, layout=layout)

plot_url = py.plot(fig, filename='GFW/communitySIZEc_trend')
# Out:
# C:\Users\Wayne\Anaconda\lib\site-packages\requests\packages\urllib3\util\ssl_.py:90: InsecurePlatformWarning:
#
# A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.

# %%
py.sign_in('cosmopolitanvan', 'jnv1ti79zi')

trace1 = Scatter(
    x = community_count['Time frame'],
    y = community_count['# of communities'],
    mode ='lines+markers',
    name ='# of clusters',
    error_y=ErrorY(
        color='rgb(0,116,217)',
        thickness=1,
        width=1
    ),
    error_x=ErrorX(
        color='black',
        thickness='1',
        width='2',
        copy_ystyle=True
    ),
    marker=Marker(
        color='rgb(19, 27, 88)',
        size=6,
        symbol='dot',
        line=Line(
            color='white',
            width=6
        ),
        opacity=1,
        maxdisplayed=0
    ),
    line=Line(
        color='rgb(19, 27, 88)',
        width=6,
        dash='solid',
        shape='linear'
    ),
    fill='none',
    opacity=1,
    visible=True,
    xsrc='cosmopolitanvan:195:f4aa23',
    ysrc='cosmopolitanvan:195:eef505'
)

data3 = Data([trace1])
layout = Layout(
    title='The # of Clusters',
    titlefont=Font(
        family='"Open sans", verdana, arial, sans-serif',
        size=17,
        color='#444'
    ),
    font=Font(
        family='"Droid Sans", sans-serif',
        size=12,
        color='#444'
    ),
    autosize=True,
    width=1043,
    height=480,
    xaxis=XAxis(
        title='Time frame',
        titlefont=Font(
            family='"Verdana", monospace',
            size=12,
            color='black'
        ),
        range=[-0.3540280857354028, 4.354028085735402],
        type='category',
        rangemode='normal',
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        nticks=0,
        ticks='',
        showticklabels=True,
        ticklen=6,
        tickcolor='rgba(0, 0, 0, 0)',
        tickangle='auto',
        tickfont=Font(
            family='"Verdana", monospace',
            size=10,
            color='black'
        ),
        mirror='allticks',
        gridcolor='white',
        gridwidth=1,
        zerolinecolor='#444',
        zerolinewidth=1,
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    yaxis=YAxis(
        titlefont=Font(
            family='"Verdana", monospace',
            size=12,
            color='black'
        ),
        range=[0.5346071428571428, 0.8176928571428572],
        type='linear',
        rangemode='normal',
        autorange=True,
        showgrid=True,
        zeroline=False,
        showline=False,
        nticks=0,
        ticks='',
        showticklabels=True,
        ticklen=6,
        tickcolor='rgba(0, 0, 0, 0)',
        tickangle='auto',
        tickfont=Font(
            family='"Verdana", monospace',
            size=10,
            color='black'
        ),
        exponentformat='B',
        showexponent='all',
        mirror='allticks',
        gridcolor='white',
        gridwidth=1,
        zerolinecolor='#444',
        zerolinewidth=1,
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    legend=Legend(
        x=1.02,
        y=1,
        traceorder='normal',
        font=Font(
            family='"Open sans", verdana, arial, sans-serif',
            size=12,
            color='#444'
        ),
        bgcolor='#fff',
        bordercolor='#444',
        borderwidth=0,
        xref='paper',
        yref='paper'
    ),
    paper_bgcolor='rgb(213, 226, 233)',
    plot_bgcolor='rgb(213, 226, 233)',
    hovermode='x',
    dragmode='zoom',
    separators='.,',
    bargap=0.2,
    hidesources=False
)

fig = Figure(data=data3, layout=layout)

plot_url = py.plot(fig, filename='GFW/communitycount_trend')
